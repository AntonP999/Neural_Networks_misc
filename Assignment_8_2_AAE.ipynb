# %% [markdown]
# Цель работы - реализация состязательного автокодировщика. Для этого необходимо регуляризацию латентного слоя осуществить с помощья сети-дискриминатора, вместо KL-divergence.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

from torchvision import datasets, transforms
from utils import mnist, plot_graphs, plot_mnist

# %matplotlib inline

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") 
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# Результаты с использованием бинарной кросс-энтропии как функции ошибки реконструкции получились качественнее, чем при использовании mse. Поэтому датасет оставлен в виде интервала [0, 1].

# %%
mnist_0_1 = transforms.Compose([
                transforms.ToTensor(),
              #  transforms.Normalize((0.5,), (0.5,)),
           ])

# %%
param_input_shape = 28*28
param_layers_size = (500, 501)
param_ld_size = 2
param_num_classes = 10
param_ae_loss_fn = F.binary_cross_entropy
param_batch_size = 250

# %%
train_loader, valid_loader, test_loader = mnist(batch_size=param_batch_size, valid=10000, transform=mnist_0_1)

# %%
class Encoder(nn.Module):
    # Переводит вход в латентный слой. Здесь теперь не нужны мю и сигма, достаточно z.
    def __init__(self):
        super(Encoder, self).__init__()
        self.fc1 = nn.Linear(param_input_shape, param_layers_size[0])
        self.do1 = nn.Dropout(0.3)
        self.fc2 = nn.Linear(param_layers_size[0], param_layers_size[1])
        self.do2 = nn.Dropout(0.3)
        self.z = nn.Linear(param_layers_size[1], param_ld_size)        
    
    def forward(self, x):
        x = x.view(-1, param_input_shape)
        x = torch.relu(self.do1(self.fc1(x)))
        x = torch.relu(self.do2(self.fc2(x)))
        z = self.z(x)        
        return z

class Decoder(nn.Module):
    # Восстанавливает изображение из z. На выходе сигмоид для [0, 1].
    def __init__(self):
        super(Decoder, self).__init__()
        self.fc1 = nn.Linear(param_ld_size, param_layers_size[0])
        self.do1 = nn.Dropout(0.3)
        self.fc2 = nn.Linear(param_layers_size[0], param_layers_size[1])
        self.do2 = nn.Dropout(0.3)
        self.fc3 = nn.Linear(param_layers_size[1], param_input_shape)
    
    def forward(self, x):        
        x = torch.relu(self.do1(self.fc1(x)))
        x = torch.relu(self.do2(self.fc2(x)))
        x = torch.sigmoid(self.fc3(x))
        return x

class Discriminator(nn.Module):
    # Отличает сэмпл z от сэмпла N(0, 1), для регуляризации кодировщика.
    def __init__(self):
        super(Discriminator, self).__init__()
        self.fc1 = nn.Linear(param_ld_size, param_layers_size[0])
        self.do1 = nn.Dropout(0.3)
        self.fc2 = nn.Linear(param_layers_size[0], param_layers_size[1])
        self.do2 = nn.Dropout(0.3)
        self.fc3 = nn.Linear(param_layers_size[1], 1)

    def forward(self, x):
        x = torch.relu(self.do1(self.fc1(x)))
        x = torch.relu(self.do2(self.fc2(x)))
        x = self.fc3(x)
        return x

# %%
E = Encoder()
# Оптимизатор для кодировщика по ошибке реконструкции.
E_ae_opt = optim.Adam(E.parameters(), lr=1e-3)
# Оптимизатор для кодировщика по латентному слою.
E_reg_opt = optim.Adam(E.parameters(), lr=1e-3)
E.to(device)
D = Decoder()
# Оптимизатор декодера.
D_opt = optim.Adam(D.parameters(), lr=1e-3)
D.to(device)
DC = Discriminator()
# Оптимизатор дискриминатора.
DC_opt = optim.Adam(DC.parameters(), lr=1e-3)
DC.to(device)

train_log = {'AE': [], 'E': [], "DC": []}
test_log = {'AE': [], 'E': [], "DC": []}

# %%
batch_zeros = torch.zeros((param_batch_size, 1)).to(device)
batch_ones = torch.ones((param_batch_size, 1)).to(device)
# Многомерное нормальное распределение (для истинных сэмплов).
distribution = torch.distributions.MultivariateNormal(torch.zeros(param_ld_size), torch.eye(param_ld_size))

# %%
def train(epoch, E, D, DC, log=None):
    train_size = len(train_loader.sampler)
    for batch_idx, (data, target) in enumerate(train_loader):        
        data = data.to(device)
        target = target.to(device)

        # Обучение всего автокодировщика восстанавливать изображения.
        E.zero_grad()
        D.zero_grad()
        DC.zero_grad()
        z = E(data)
        recon = D(z)
        AE_loss = param_ae_loss_fn(recon, data.view(-1, param_input_shape))
        AE_loss.backward()
        D_opt.step()
        E_ae_opt.step()

        # Обучение дискриминатора отличать истинное N(0, 1) от выхода кодировщика.
        E.zero_grad()
        D.zero_grad()
        DC.zero_grad()
        
        fake_z = DC(E(data))
        true_z = DC(distribution.sample((param_batch_size, )).to(device))
        fake_loss = F.binary_cross_entropy_with_logits(fake_z, batch_zeros)
        true_loss = F.binary_cross_entropy_with_logits(true_z, batch_ones)

        DC_loss = 0.5*(fake_loss + true_loss)
        DC_loss.backward()
        DC_opt.step()

        # Обучение кодировщика выдавать то, что дискриминатор не отличит от требуемого распределения.
        E.zero_grad()
        D.zero_grad()
        DC.zero_grad()
        
        fake_z = DC(E(data))
        E_loss = F.binary_cross_entropy_with_logits(fake_z, batch_ones)
        E_loss.backward()
        E_reg_opt.step()

        if batch_idx % 100 == 0:
            line = 'Train Epoch: {} [{}/{} ({:.0f}%)]\tLosses '.format(
                epoch, batch_idx * len(data), train_size, 100. * batch_idx / len(train_loader))
            losses = 'AE: {:.4f}, E: {:.4f}, DC: {:.4f}'.format(AE_loss.item(), E_loss.item(), DC_loss.item())
            print(line + losses)

    else:
        batch_idx += 1
        line = 'Train Epoch: {} [{}/{} ({:.0f}%)]\tLosses '.format(
            epoch, batch_idx * len(data), train_size, 100. * batch_idx / len(train_loader))
        losses = 'AE: {:.4f}, E: {:.4f}, DC:{:.4f}'.format(AE_loss.item(), E_loss.item(), DC_loss.item())
        print(line + losses)
        log['AE'].append(AE_loss.item())
        log['E'].append(E_loss.item())
        log['DC'].append(DC_loss.item())

# %%
def test(E, D, DC, loader, epoch, log=None):
    test_size = len(loader)
    AE_loss = 0.
    E_loss = 0.
    DC_loss = 0.    
    test_loss = {'AE': 0., 'E': 0., "DC": 0}
    with torch.no_grad():
        for data, target in loader:
            data = data.to(device)
            target = target.to(device)

            z = E(data)
            recon = D(z)
            AE_loss += param_ae_loss_fn(recon, data.view(-1, param_input_shape)).item()

            fake_z = DC(z)
            true_z = DC(distribution.sample((param_batch_size, )).to(device))
            fake_loss = F.binary_cross_entropy_with_logits(fake_z, batch_zeros).item()
            true_loss = F.binary_cross_entropy_with_logits(true_z, batch_ones).item()
            DC_loss += 0.5*(fake_loss + true_loss)
            
            E_loss += F.binary_cross_entropy_with_logits(fake_z, batch_ones).item()            
    
    AE_loss /= test_size
    E_loss /= test_size
    DC_loss /= test_size
    
    report = 'Test losses. AE: {:.4f}, E: {:.4f}, DC: {:.4f}\n'.format(AE_loss, E_loss, DC_loss)
    print(report)
    if log is not None:
        log['AE'].append(AE_loss)
        log['E'].append(E_loss)
        log['DC'].append(DC_loss)

# %%
for epoch in range(1, 51):
    E.train()
    D.train()
    DC.train()
    train(epoch, E, D, DC, train_log)
    E.eval()
    D.eval()
    DC.eval()
    test(E, D, DC, valid_loader, epoch, test_log)
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Losses AE: 0.6946, E: 0.6921, DC: 0.6837
# Train Epoch: 1 [25000/50000 (50%)]	Losses AE: 0.2356, E: 1.1169, DC: 0.8402
# Train Epoch: 1 [50000/50000 (100%)]	Losses AE: 0.2189, E: 0.7302, DC:0.6837
# Test losses. AE: 0.2185, E: 0.6958, DC: 0.6928
#
# Train Epoch: 2 [0/50000 (0%)]	Losses AE: 0.2193, E: 0.7308, DC: 0.6832
# Train Epoch: 2 [25000/50000 (50%)]	Losses AE: 0.2132, E: 0.7238, DC: 0.6875
# Train Epoch: 2 [50000/50000 (100%)]	Losses AE: 0.2119, E: 0.7513, DC:0.6927
# Test losses. AE: 0.2129, E: 0.6891, DC: 0.6923
#
# Train Epoch: 3 [0/50000 (0%)]	Losses AE: 0.2208, E: 0.7345, DC: 0.6730
# Train Epoch: 3 [25000/50000 (50%)]	Losses AE: 0.2128, E: 0.7709, DC: 0.6758
# Train Epoch: 3 [50000/50000 (100%)]	Losses AE: 0.2098, E: 0.6989, DC:0.6697
# Test losses. AE: 0.2091, E: 0.6475, DC: 0.6903
#
# Train Epoch: 4 [0/50000 (0%)]	Losses AE: 0.2127, E: 0.7166, DC: 0.6843
# Train Epoch: 4 [25000/50000 (50%)]	Losses AE: 0.2080, E: 0.7376, DC: 0.7000
# Train Epoch: 4 [50000/50000 (100%)]	Losses AE: 0.2102, E: 0.6945, DC:0.6861
# Test losses. AE: 0.2068, E: 0.6461, DC: 0.6962
#
# Train Epoch: 5 [0/50000 (0%)]	Losses AE: 0.2050, E: 0.6806, DC: 0.6867
# Train Epoch: 5 [25000/50000 (50%)]	Losses AE: 0.2129, E: 0.7112, DC: 0.6899
# Train Epoch: 5 [50000/50000 (100%)]	Losses AE: 0.2079, E: 0.7197, DC:0.6863
# Test losses. AE: 0.2025, E: 0.6683, DC: 0.6952
#
# Train Epoch: 6 [0/50000 (0%)]	Losses AE: 0.2073, E: 0.6959, DC: 0.6954
# Train Epoch: 6 [25000/50000 (50%)]	Losses AE: 0.2034, E: 0.6982, DC: 0.6921
# Train Epoch: 6 [50000/50000 (100%)]	Losses AE: 0.2117, E: 0.6990, DC:0.6862
# Test losses. AE: 0.2021, E: 0.6606, DC: 0.7011
#
# Train Epoch: 7 [0/50000 (0%)]	Losses AE: 0.2090, E: 0.7140, DC: 0.6835
# Train Epoch: 7 [25000/50000 (50%)]	Losses AE: 0.2106, E: 0.7212, DC: 0.6866
# Train Epoch: 7 [50000/50000 (100%)]	Losses AE: 0.2130, E: 0.6984, DC:0.6865
# Test losses. AE: 0.2059, E: 0.6773, DC: 0.6983
#
# Train Epoch: 8 [0/50000 (0%)]	Losses AE: 0.2151, E: 0.7757, DC: 0.6826
# Train Epoch: 8 [25000/50000 (50%)]	Losses AE: 0.2059, E: 0.7142, DC: 0.6836
# Train Epoch: 8 [50000/50000 (100%)]	Losses AE: 0.2153, E: 0.6843, DC:0.6854
# Test losses. AE: 0.1996, E: 0.6638, DC: 0.6946
#
# Train Epoch: 9 [0/50000 (0%)]	Losses AE: 0.2039, E: 0.7004, DC: 0.6858
# Train Epoch: 9 [25000/50000 (50%)]	Losses AE: 0.2024, E: 0.7048, DC: 0.6907
# Train Epoch: 9 [50000/50000 (100%)]	Losses AE: 0.2079, E: 0.7204, DC:0.6784
# Test losses. AE: 0.2007, E: 0.6787, DC: 0.6995
#
# Train Epoch: 10 [0/50000 (0%)]	Losses AE: 0.2091, E: 0.7147, DC: 0.7004
# Train Epoch: 10 [25000/50000 (50%)]	Losses AE: 0.2168, E: 0.6960, DC: 0.6960
# Train Epoch: 10 [50000/50000 (100%)]	Losses AE: 0.2100, E: 0.7245, DC:0.6853
# Test losses. AE: 0.1996, E: 0.7008, DC: 0.6980
#
# Train Epoch: 11 [0/50000 (0%)]	Losses AE: 0.2129, E: 0.7206, DC: 0.6847
# Train Epoch: 11 [25000/50000 (50%)]	Losses AE: 0.2063, E: 0.7400, DC: 0.6823
# Train Epoch: 11 [50000/50000 (100%)]	Losses AE: 0.2071, E: 0.7003, DC:0.6883
# Test losses. AE: 0.1985, E: 0.6891, DC: 0.6939
#
# Train Epoch: 12 [0/50000 (0%)]	Losses AE: 0.2000, E: 0.7069, DC: 0.6897
# Train Epoch: 12 [25000/50000 (50%)]	Losses AE: 0.2079, E: 0.6929, DC: 0.6871
# Train Epoch: 12 [50000/50000 (100%)]	Losses AE: 0.2164, E: 0.7185, DC:0.6879
# Test losses. AE: 0.1995, E: 0.7040, DC: 0.6959
#
# Train Epoch: 13 [0/50000 (0%)]	Losses AE: 0.2035, E: 0.7136, DC: 0.6919
# Train Epoch: 13 [25000/50000 (50%)]	Losses AE: 0.2068, E: 0.7149, DC: 0.6892
# Train Epoch: 13 [50000/50000 (100%)]	Losses AE: 0.2041, E: 0.6965, DC:0.6892
# Test losses. AE: 0.2005, E: 0.6732, DC: 0.6963
#
# Train Epoch: 14 [0/50000 (0%)]	Losses AE: 0.2027, E: 0.6907, DC: 0.6906
# Train Epoch: 14 [25000/50000 (50%)]	Losses AE: 0.2064, E: 0.6940, DC: 0.6877
# Train Epoch: 14 [50000/50000 (100%)]	Losses AE: 0.2064, E: 0.6987, DC:0.6933
# Test losses. AE: 0.1973, E: 0.6880, DC: 0.6940
#
# Train Epoch: 15 [0/50000 (0%)]	Losses AE: 0.2007, E: 0.6925, DC: 0.6961
# Train Epoch: 15 [25000/50000 (50%)]	Losses AE: 0.2020, E: 0.6932, DC: 0.6896
# Train Epoch: 15 [50000/50000 (100%)]	Losses AE: 0.2044, E: 0.6873, DC:0.6943
# Test losses. AE: 0.1988, E: 0.6717, DC: 0.6958
#
# Train Epoch: 16 [0/50000 (0%)]	Losses AE: 0.2072, E: 0.6807, DC: 0.6913
# Train Epoch: 16 [25000/50000 (50%)]	Losses AE: 0.2022, E: 0.6915, DC: 0.6904
# Train Epoch: 16 [50000/50000 (100%)]	Losses AE: 0.2003, E: 0.6839, DC:0.6943
# Test losses. AE: 0.1978, E: 0.6769, DC: 0.6960
#
# Train Epoch: 17 [0/50000 (0%)]	Losses AE: 0.2081, E: 0.6862, DC: 0.6928
# Train Epoch: 17 [25000/50000 (50%)]	Losses AE: 0.1968, E: 0.6953, DC: 0.6924
# Train Epoch: 17 [50000/50000 (100%)]	Losses AE: 0.2044, E: 0.6902, DC:0.6932
# Test losses. AE: 0.1978, E: 0.6822, DC: 0.6968
#
# Train Epoch: 18 [0/50000 (0%)]	Losses AE: 0.2028, E: 0.7005, DC: 0.6931
# Train Epoch: 18 [25000/50000 (50%)]	Losses AE: 0.2064, E: 0.6985, DC: 0.6938
# Train Epoch: 18 [50000/50000 (100%)]	Losses AE: 0.2029, E: 0.6991, DC:0.6884
# Test losses. AE: 0.1974, E: 0.6880, DC: 0.6970
#
# Train Epoch: 19 [0/50000 (0%)]	Losses AE: 0.1953, E: 0.7017, DC: 0.6875
# Train Epoch: 19 [25000/50000 (50%)]	Losses AE: 0.2070, E: 0.7167, DC: 0.6932
# Train Epoch: 19 [50000/50000 (100%)]	Losses AE: 0.2025, E: 0.6880, DC:0.6942
# Test losses. AE: 0.1954, E: 0.6801, DC: 0.6974
#
# Train Epoch: 20 [0/50000 (0%)]	Losses AE: 0.2002, E: 0.6916, DC: 0.6926
# Train Epoch: 20 [25000/50000 (50%)]	Losses AE: 0.2061, E: 0.6758, DC: 0.6952
# Train Epoch: 20 [50000/50000 (100%)]	Losses AE: 0.1932, E: 0.6929, DC:0.6933
# Test losses. AE: 0.1969, E: 0.6910, DC: 0.6954
#
# Train Epoch: 21 [0/50000 (0%)]	Losses AE: 0.2057, E: 0.6979, DC: 0.6929
# Train Epoch: 21 [25000/50000 (50%)]	Losses AE: 0.2086, E: 0.6999, DC: 0.6975
# Train Epoch: 21 [50000/50000 (100%)]	Losses AE: 0.2049, E: 0.7020, DC:0.6970
# Test losses. AE: 0.1961, E: 0.6955, DC: 0.6958
#
# Train Epoch: 22 [0/50000 (0%)]	Losses AE: 0.2029, E: 0.7071, DC: 0.6950
# Train Epoch: 22 [25000/50000 (50%)]	Losses AE: 0.2083, E: 0.6935, DC: 0.6960
# Train Epoch: 22 [50000/50000 (100%)]	Losses AE: 0.1983, E: 0.6999, DC:0.6922
# Test losses. AE: 0.1974, E: 0.6852, DC: 0.6967
#
# Train Epoch: 23 [0/50000 (0%)]	Losses AE: 0.2078, E: 0.6974, DC: 0.6940
# Train Epoch: 23 [25000/50000 (50%)]	Losses AE: 0.2040, E: 0.7072, DC: 0.6945
# Train Epoch: 23 [50000/50000 (100%)]	Losses AE: 0.2074, E: 0.7061, DC:0.6865
# Test losses. AE: 0.1945, E: 0.6961, DC: 0.6950
#
# Train Epoch: 24 [0/50000 (0%)]	Losses AE: 0.2036, E: 0.7079, DC: 0.6916
# Train Epoch: 24 [25000/50000 (50%)]	Losses AE: 0.2005, E: 0.6992, DC: 0.6901
# Train Epoch: 24 [50000/50000 (100%)]	Losses AE: 0.1997, E: 0.6825, DC:0.6901
# Test losses. AE: 0.1931, E: 0.6789, DC: 0.6932
#
# Train Epoch: 25 [0/50000 (0%)]	Losses AE: 0.2090, E: 0.6816, DC: 0.6916
# Train Epoch: 25 [25000/50000 (50%)]	Losses AE: 0.2072, E: 0.6936, DC: 0.6942
# Train Epoch: 25 [50000/50000 (100%)]	Losses AE: 0.1958, E: 0.6771, DC:0.6929
# Test losses. AE: 0.1930, E: 0.6775, DC: 0.6943
#
# Train Epoch: 26 [0/50000 (0%)]	Losses AE: 0.1960, E: 0.6804, DC: 0.6907
# Train Epoch: 26 [25000/50000 (50%)]	Losses AE: 0.2016, E: 0.6991, DC: 0.6938
# Train Epoch: 26 [50000/50000 (100%)]	Losses AE: 0.2034, E: 0.6934, DC:0.6912
# Test losses. AE: 0.1928, E: 0.6885, DC: 0.6948
#
# Train Epoch: 27 [0/50000 (0%)]	Losses AE: 0.2048, E: 0.7023, DC: 0.6882
# Train Epoch: 27 [25000/50000 (50%)]	Losses AE: 0.1976, E: 0.6976, DC: 0.6921
# Train Epoch: 27 [50000/50000 (100%)]	Losses AE: 0.2015, E: 0.6983, DC:0.6938
# Test losses. AE: 0.1919, E: 0.6948, DC: 0.6946
#
# Train Epoch: 28 [0/50000 (0%)]	Losses AE: 0.2026, E: 0.6993, DC: 0.6950
# Train Epoch: 28 [25000/50000 (50%)]	Losses AE: 0.1989, E: 0.6951, DC: 0.6921
# Train Epoch: 28 [50000/50000 (100%)]	Losses AE: 0.1977, E: 0.7027, DC:0.6944
# Test losses. AE: 0.1956, E: 0.6991, DC: 0.6952
#
# Train Epoch: 29 [0/50000 (0%)]	Losses AE: 0.2070, E: 0.7028, DC: 0.6934
# Train Epoch: 29 [25000/50000 (50%)]	Losses AE: 0.1995, E: 0.6932, DC: 0.6936
# Train Epoch: 29 [50000/50000 (100%)]	Losses AE: 0.1994, E: 0.6941, DC:0.6922
# Test losses. AE: 0.1924, E: 0.6924, DC: 0.6930
#
# Train Epoch: 30 [0/50000 (0%)]	Losses AE: 0.1988, E: 0.6961, DC: 0.6926
# Train Epoch: 30 [25000/50000 (50%)]	Losses AE: 0.1999, E: 0.6932, DC: 0.6932
# Train Epoch: 30 [50000/50000 (100%)]	Losses AE: 0.1883, E: 0.6978, DC:0.6925
# Test losses. AE: 0.1923, E: 0.6911, DC: 0.6940
#
# Train Epoch: 31 [0/50000 (0%)]	Losses AE: 0.1946, E: 0.6930, DC: 0.6930
# Train Epoch: 31 [25000/50000 (50%)]	Losses AE: 0.1988, E: 0.6944, DC: 0.6912
# Train Epoch: 31 [50000/50000 (100%)]	Losses AE: 0.1980, E: 0.6842, DC:0.6940
# Test losses. AE: 0.1915, E: 0.6814, DC: 0.6944
#
# Train Epoch: 32 [0/50000 (0%)]	Losses AE: 0.1994, E: 0.6868, DC: 0.6929
# Train Epoch: 32 [25000/50000 (50%)]	Losses AE: 0.1933, E: 0.6921, DC: 0.6922
# Train Epoch: 32 [50000/50000 (100%)]	Losses AE: 0.1964, E: 0.6996, DC:0.6936
# Test losses. AE: 0.1911, E: 0.6939, DC: 0.6941
#
# Train Epoch: 33 [0/50000 (0%)]	Losses AE: 0.2057, E: 0.6944, DC: 0.6929
# Train Epoch: 33 [25000/50000 (50%)]	Losses AE: 0.2052, E: 0.6966, DC: 0.6919
# Train Epoch: 33 [50000/50000 (100%)]	Losses AE: 0.1995, E: 0.6889, DC:0.6953
# Test losses. AE: 0.1927, E: 0.6845, DC: 0.6950
#
# Train Epoch: 34 [0/50000 (0%)]	Losses AE: 0.1962, E: 0.6853, DC: 0.6933
# Train Epoch: 34 [25000/50000 (50%)]	Losses AE: 0.1948, E: 0.6955, DC: 0.6933
# Train Epoch: 34 [50000/50000 (100%)]	Losses AE: 0.2031, E: 0.6942, DC:0.6909
# Test losses. AE: 0.1955, E: 0.6840, DC: 0.6950
#
# Train Epoch: 35 [0/50000 (0%)]	Losses AE: 0.1972, E: 0.6942, DC: 0.6912
# Train Epoch: 35 [25000/50000 (50%)]	Losses AE: 0.2014, E: 0.6820, DC: 0.6946
# Train Epoch: 35 [50000/50000 (100%)]	Losses AE: 0.2001, E: 0.6912, DC:0.6951
# Test losses. AE: 0.1941, E: 0.6897, DC: 0.6947
#
# Train Epoch: 36 [0/50000 (0%)]	Losses AE: 0.1971, E: 0.6920, DC: 0.6927
# Train Epoch: 36 [25000/50000 (50%)]	Losses AE: 0.1935, E: 0.6941, DC: 0.6919
# Train Epoch: 36 [50000/50000 (100%)]	Losses AE: 0.1975, E: 0.6958, DC:0.6940
# Test losses. AE: 0.1919, E: 0.6933, DC: 0.6946
#
# Train Epoch: 37 [0/50000 (0%)]	Losses AE: 0.1870, E: 0.6977, DC: 0.6948
# Train Epoch: 37 [25000/50000 (50%)]	Losses AE: 0.1965, E: 0.6943, DC: 0.6922
# Train Epoch: 37 [50000/50000 (100%)]	Losses AE: 0.1938, E: 0.6993, DC:0.6928
# Test losses. AE: 0.1935, E: 0.6966, DC: 0.6943
#
# Train Epoch: 38 [0/50000 (0%)]	Losses AE: 0.2054, E: 0.6959, DC: 0.6925
# Train Epoch: 38 [25000/50000 (50%)]	Losses AE: 0.2005, E: 0.6996, DC: 0.6919
# Train Epoch: 38 [50000/50000 (100%)]	Losses AE: 0.1953, E: 0.6906, DC:0.6940
# Test losses. AE: 0.1902, E: 0.6907, DC: 0.6944
#
# Train Epoch: 39 [0/50000 (0%)]	Losses AE: 0.1960, E: 0.6930, DC: 0.6935
# Train Epoch: 39 [25000/50000 (50%)]	Losses AE: 0.1912, E: 0.6973, DC: 0.6934
# Train Epoch: 39 [50000/50000 (100%)]	Losses AE: 0.1931, E: 0.6866, DC:0.6940
# Test losses. AE: 0.1886, E: 0.6855, DC: 0.6937
#
# Train Epoch: 40 [0/50000 (0%)]	Losses AE: 0.1934, E: 0.6865, DC: 0.6943
# Train Epoch: 40 [25000/50000 (50%)]	Losses AE: 0.1993, E: 0.6917, DC: 0.6925
# Train Epoch: 40 [50000/50000 (100%)]	Losses AE: 0.2037, E: 0.6913, DC:0.6917
# Test losses. AE: 0.1946, E: 0.6861, DC: 0.6948
#
# Train Epoch: 41 [0/50000 (0%)]	Losses AE: 0.1983, E: 0.6917, DC: 0.6954
# Train Epoch: 41 [25000/50000 (50%)]	Losses AE: 0.1976, E: 0.6888, DC: 0.6934
# Train Epoch: 41 [50000/50000 (100%)]	Losses AE: 0.1864, E: 0.6951, DC:0.6938
# Test losses. AE: 0.1870, E: 0.6953, DC: 0.6936
#
# Train Epoch: 42 [0/50000 (0%)]	Losses AE: 0.1938, E: 0.6959, DC: 0.6939
# Train Epoch: 42 [25000/50000 (50%)]	Losses AE: 0.1979, E: 0.6833, DC: 0.6940
# Train Epoch: 42 [50000/50000 (100%)]	Losses AE: 0.1944, E: 0.6946, DC:0.6925
# Test losses. AE: 0.1875, E: 0.6922, DC: 0.6935
#
# Train Epoch: 43 [0/50000 (0%)]	Losses AE: 0.1881, E: 0.6962, DC: 0.6916
# Train Epoch: 43 [25000/50000 (50%)]	Losses AE: 0.1948, E: 0.6863, DC: 0.6940
# Train Epoch: 43 [50000/50000 (100%)]	Losses AE: 0.1981, E: 0.6957, DC:0.6932
# Test losses. AE: 0.1872, E: 0.6937, DC: 0.6937
#
# Train Epoch: 44 [0/50000 (0%)]	Losses AE: 0.1910, E: 0.6961, DC: 0.6926
# Train Epoch: 44 [25000/50000 (50%)]	Losses AE: 0.1932, E: 0.6934, DC: 0.6926
# Train Epoch: 44 [50000/50000 (100%)]	Losses AE: 0.1973, E: 0.6802, DC:0.6916
# Test losses. AE: 0.1923, E: 0.6822, DC: 0.6930
#
# Train Epoch: 45 [0/50000 (0%)]	Losses AE: 0.1852, E: 0.6815, DC: 0.6952
# Train Epoch: 45 [25000/50000 (50%)]	Losses AE: 0.2423, E: 0.6655, DC: 0.7020
# Train Epoch: 45 [50000/50000 (100%)]	Losses AE: 0.2063, E: 0.6971, DC:0.6930
# Test losses. AE: 0.2022, E: 0.6972, DC: 0.6933
#
# Train Epoch: 46 [0/50000 (0%)]	Losses AE: 0.2029, E: 0.6980, DC: 0.6929
# Train Epoch: 46 [25000/50000 (50%)]	Losses AE: 0.2023, E: 0.6858, DC: 0.6943
# Train Epoch: 46 [50000/50000 (100%)]	Losses AE: 0.1981, E: 0.6878, DC:0.6926
# Test losses. AE: 0.1900, E: 0.6873, DC: 0.6934
#
# Train Epoch: 47 [0/50000 (0%)]	Losses AE: 0.1951, E: 0.6897, DC: 0.6928
# Train Epoch: 47 [25000/50000 (50%)]	Losses AE: 0.1912, E: 0.6961, DC: 0.6945
# Train Epoch: 47 [50000/50000 (100%)]	Losses AE: 0.1993, E: 0.6859, DC:0.6930
# Test losses. AE: 0.1888, E: 0.6838, DC: 0.6935
#
# Train Epoch: 48 [0/50000 (0%)]	Losses AE: 0.2023, E: 0.6859, DC: 0.6920
# Train Epoch: 48 [25000/50000 (50%)]	Losses AE: 0.1957, E: 0.6832, DC: 0.6938
# Train Epoch: 48 [50000/50000 (100%)]	Losses AE: 0.1957, E: 0.6897, DC:0.6941
# Test losses. AE: 0.1883, E: 0.6887, DC: 0.6935
#
# Train Epoch: 49 [0/50000 (0%)]	Losses AE: 0.1921, E: 0.6906, DC: 0.6931
# Train Epoch: 49 [25000/50000 (50%)]	Losses AE: 0.1971, E: 0.6914, DC: 0.6928
# Train Epoch: 49 [50000/50000 (100%)]	Losses AE: 0.2004, E: 0.6949, DC:0.6927
# Test losses. AE: 0.1878, E: 0.6936, DC: 0.6937
#
# Train Epoch: 50 [0/50000 (0%)]	Losses AE: 0.1937, E: 0.6950, DC: 0.6938
# Train Epoch: 50 [25000/50000 (50%)]	Losses AE: 0.1886, E: 0.6974, DC: 0.6933
# Train Epoch: 50 [50000/50000 (100%)]	Losses AE: 0.1966, E: 0.7084, DC:0.6927
# Test losses. AE: 0.1891, E: 0.7059, DC: 0.6936

# %% [markdown]
# При обучении модели ошибки кодировщика и дискриминатора довольно быстро сходятся к 0,69. Но ошибка восстановления изображения очень медленно снижается и практически останавливается под конец обучения.

# %%
plt.figure(figsize=(16, 16))
plt.subplot(3, 1, 1)
plt.plot(train_log["AE"], label="Train reconstruction loss")
plt.plot(test_log["AE"], label="Test reconstruction loss")
plt.legend()
plt.subplot(3, 1, 2)
plt.plot(train_log["E"], label="Train encoder loss")
plt.plot(test_log["E"], label="Test encoder loss")
plt.legend()
plt.subplot(3, 1, 3)
plt.plot(train_log["DC"], label="Train discriminator loss")
plt.plot(test_log["DC"], label="Test discriminator loss")
plt.legend()
plt.show()

# %% [markdown]
# Вывод сгенерированных автокодировщиком изображений по входным данным и по сэмплу нормального распределения. Изображения довольно размазанные, некоторые не совпадают с оригиналом.

# %%
data, _ = next(iter(test_loader))
data = data[:50].to(device)
output = D(E(data))
to_plot = output.view(-1, 1, 28, 28).clamp(0, 1).data.cpu().numpy()
decoded = D(distribution.sample((param_batch_size, ))[:10].to(device))
dec_to_plot = ((decoded.view(-1, 1, 28, 28)+1)*0.5).clamp(0, 1).data.cpu().numpy()

plot_mnist(data.data.cpu().numpy(), (5, 10))
plot_mnist(to_plot, (5, 10))
plot_mnist(dec_to_plot, (1, 10))

# %% [markdown]
# Отрисовка места некоторых цифр в латентном пространстве. Интересно было бы проверить распределение в нем на нормальность.

# %%
data, _ = next(iter(test_loader))
data = data.to(device)
z = E(data)
output = D(z)

plt.figure(figsize=(8, 12))
for i in range(5):
    plt.subplot(5, 3, 3*i + 1)
    plt.imshow(data[i].cpu().reshape(28, 28), vmin=0, vmax=1,  interpolation='none',cmap=plt.get_cmap('gray'))
    plt.title("Test input")
        
    plt.subplot(5, 3, 3*i + 2)
    plt.scatter(z.cpu().detach()[:,0],z.cpu().detach()[:,1], c='gray', alpha=0.5)
    #plt.scatter(m.cpu().detach()[i,0],m.cpu().detach()[i,1], c='green', s=64, alpha=0.5)
    plt.scatter(z.cpu().detach()[i,0],z.cpu().detach()[i,1], c='blue', s=16, alpha=0.5)
       
    plt.xlim((-5,5))
    plt.ylim((-5,5))
    plt.title("Latent Space")
        
    plt.subplot(5, 3, 3*i + 3)
    plt.imshow(output.cpu().detach()[i].reshape(28, 28), vmin=0, vmax=1, interpolation='none',cmap=plt.get_cmap('gray'))
    plt.title("Reconstruction")
        
    plt.tight_layout()

# %% [markdown]
# Карта скрытого пространства. Видно, что оно обладает выраженной структурой, при этом наиболее похожие цифры (3, 5, 8) смещены к центру. Хотя цифру 6 можно найти и слева и снизу.

# %%
nx = ny = 20
x_values = np.linspace(-3, 3, nx)
y_values = np.linspace(-3, 3, ny)
canvas = np.empty((28*ny, 28*nx))
for i, yi in enumerate(x_values):
    for j, xi in enumerate(y_values):
        d = np.zeros([1,param_ld_size],dtype='float32')
        z_mu = np.array([[xi, yi]])
        d[0,:2] = z_mu        
        x_mean = D(torch.Tensor(d).to(device))
        canvas[(nx-i-1)*28:(nx-i)*28, j*28:(j+1)*28] = x_mean.cpu().detach()[0].reshape(28, 28)

plt.figure(figsize=(8, 8))        
Xi, Yi = np.meshgrid(x_values, y_values)
plt.imshow(canvas, origin="upper", vmin=0, vmax=1,interpolation='none',cmap=plt.get_cmap('gray'))
plt.tight_layout()
